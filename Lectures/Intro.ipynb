# %% [markdown]
# We are going to look at three main class of problems in this course.
#
# (i) Linear Programming: Objective function and contraints are linear.
#
# (ii) Unconstrained optimization
#
# (iii) Constrained optimization (this is slightly a misnomer; Linear Programming falls under this class. We will be looking at constrained optimization problems that are not Linear Programming).
